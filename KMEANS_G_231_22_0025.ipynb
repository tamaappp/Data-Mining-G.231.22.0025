# %%
#K-Means Clustering

#Importing the libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-51a7c41c-ffe4-4fd5-a6e2-e026b03ed1f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51a7c41c-ffe4-4fd5-a6e2-e026b03ed1f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv('Mall_Customers.csv')
X = dataset.iloc[:,[3,4]].values
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Menggunakan metode elbow untuk menemukan jumlah cluster yang optimal

from sklearn.cluster import KMeans
wcss =[]
for i in range (1,11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter =300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

#plot grafik
#WCSS
#WCSS
plt.plot(range(1,11),wcss)
plt.title('Metode Elbow')
plt.xlabel('Jumlah Cluster')
plt.ylabel('WCSS')
plt.show()

# %%
# Menerapkan KMeans ke dataset dengan jumlah cluster optimal

kmeans KMeans(n_clusters= 5, init 'k-means++', max_iter = 300, n_init 10, random_state = 0)
y_kmeans kmeans.fit_predict(x)

# Visualising the clusters

plt.scatter(X[y_kmeans == 0, 0], x[y_kmeans == 0,1],5 = 100, c='red', label = 'Cluster 1')

plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1,1],5 = 100, c='blue', label = 'Cluster 2')

plt.scatter (X[y_kmeans == 2, 0], X[y_kmeans == 2,1],5 = 100, c='green', label = 'Cluster 3')

plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3,1],5 = 100, c='cyan', label = 'Cluster 4')

plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4,1],5 = 100, c='magenta", label = 'Cluster 5')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s = 300, c 'yellow', label 'Centroids')

plt.title('Clusters dari Client')
plt.xlabel('Annual Income (k$)*)
plt.ylabel('Spending score (1-100)')
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-19-a00a926953d3>", line 16
#     plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4,1],5 = 100, c='magenta", label = 'Cluster 5')
#                                                                                                 ^
# SyntaxError: unterminated string literal (detected at line 16)
